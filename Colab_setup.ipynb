# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session.

# %%
# !pwd
# Out:
# /emg2qwerty-priv

# %%
# !pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/stepanhruda/camel-kenlm.git@a6e906b2b30497dd999cb9c84c42c5111f8616e0 (from -r requirements.txt (line 33))
#   Cloning https://github.com/stepanhruda/camel-kenlm.git (to revision a6e906b2b30497dd999cb9c84c42c5111f8616e0) to /tmp/pip-req-build-qv515iy2
#   Running command git clone --filter=blob:none --quiet https://github.com/stepanhruda/camel-kenlm.git /tmp/pip-req-build-qv515iy2
#   Running command git rev-parse -q --verify 'sha^a6e906b2b30497dd999cb9c84c42c5111f8616e0'
#   Running command git fetch -q https://github.com/stepanhruda/camel-kenlm.git a6e906b2b30497dd999cb9c84c42c5111f8616e0
#   Running command git checkout -q a6e906b2b30497dd999cb9c84c42c5111f8616e0
#   Resolved https://github.com/stepanhruda/camel-kenlm.git to commit a6e906b2b30497dd999cb9c84c42c5111f8616e0
# doneuild dependencies ...
# doneGetting requirements to build wheel ...
# donePreparing metadata (pyproject.toml) ...
# Requirement already satisfied: click==8.1.7 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: datasets==2.19.2 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: h5py==3.11.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.11.0)
# Requirement already satisfied: hydra-core==1.3.2 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: hydra-submitit-launcher==1.2.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: hypothesis==6.97.6 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (6.97.6)
# Requirement already satisfied: lightning-bolts==0.7.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: mne-bids==0.15.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.15.0)
# Requirement already satisfied: nltk==3.8.1 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (3.8.1)
# Requirement already satisfied: numpy==1.24.4 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.24.4)
# Requirement already satisfied: omegaconf==2.3.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: pandas==2.0.3 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2.0.3)
# Requirement already satisfied: pip==24.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (24.0)
# Requirement already satisfied: pre-commit==3.7.1 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.7.1)
# Requirement already satisfied: pytest-benchmark==4.0.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (4.0.0)
# Requirement already satisfied: pytest-cov==5.0.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: pytest-env==1.1.3 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (1.1.3)
# Requirement already satisfied: pytest-mock==3.14.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (3.14.0)
# Requirement already satisfied: pytest-rerunfailures==14.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (14.0)
# Requirement already satisfied: pytest-xdist==3.5.0 in /venv/main/lib/python3.10/site-packages (from pytest-xdist[psutil]==3.5.0->-r requirements.txt (line 20)) (3.5.0)
# Requirement already satisfied: pytest==7.4.4 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (7.4.4)
# Requirement already satisfied: python-levenshtein==0.12.2 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.12.2)
# Requirement already satisfied: pytorch-lightning==1.8.6 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (1.8.6)
# Requirement already satisfied: torch==2.3.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (2.3.0)
# Requirement already satisfied: scipy==1.10.1 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.10.1)
# Requirement already satisfied: setuptools==69.5.1 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (69.5.1)
# Requirement already satisfied: torchaudio==2.3.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.3.0)
# Requirement already satisfied: torchmetrics==0.11.4 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.11.4)
# Requirement already satisfied: trio==0.23.2 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (0.23.2)
# Requirement already satisfied: unidecode==1.3.8 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (1.3.8)
# Requirement already satisfied: optuna==3.5.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (3.5.0)
# Requirement already satisfied: plotly==5.20.0 in /venv/main/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (5.20.0)
# Requirement already satisfied: filelock in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (19.0.1)
# Requirement already satisfied: pyarrow-hotfix in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: requests>=2.32.1 in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: xxhash in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: multiprocess in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /venv/main/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets==2.19.2->-r requirements.txt (line 2)) (2024.3.1)
# Requirement already satisfied: aiohttp in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: packaging in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /venv/main/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /venv/main/lib/python3.10/site-packages (from hydra-core==1.3.2->-r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: submitit>=1.3.3 in /venv/main/lib/python3.10/site-packages (from hydra-submitit-launcher==1.2.0->-r requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: attrs>=22.2.0 in /venv/main/lib/python3.10/site-packages (from hypothesis==6.97.6->-r requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /venv/main/lib/python3.10/site-packages (from hypothesis==6.97.6->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /venv/main/lib/python3.10/site-packages (from hypothesis==6.97.6->-r requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: lightning-utilities>0.3.1 in /venv/main/lib/python3.10/site-packages (from lightning-bolts==0.7.0->-r requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: torchvision>=0.10.0 in /venv/main/lib/python3.10/site-packages (from lightning-bolts==0.7.0->-r requirements.txt (line 7)) (0.18.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /venv/main/lib/python3.10/site-packages (from lightning-bolts==0.7.0->-r requirements.txt (line 7)) (2.19.0)
# Requirement already satisfied: mne>=1.5 in /venv/main/lib/python3.10/site-packages (from mne-bids==0.15.0->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: joblib in /venv/main/lib/python3.10/site-packages (from nltk==3.8.1->-r requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /venv/main/lib/python3.10/site-packages (from nltk==3.8.1->-r requirements.txt (line 9)) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /venv/main/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /venv/main/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 12)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /venv/main/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 12)) (2025.1)
# Requirement already satisfied: cfgv>=2.0.0 in /venv/main/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /venv/main/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (2.6.9)
# Requirement already satisfied: nodeenv>=0.11.1 in /venv/main/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /venv/main/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (20.29.3)
# Requirement already satisfied: py-cpuinfo in /venv/main/lib/python3.10/site-packages (from pytest-benchmark==4.0.0->-r requirements.txt (line 15)) (9.0.0)
# Requirement already satisfied: coverage>=5.2.1 in /venv/main/lib/python3.10/site-packages (from coverage[toml]>=5.2.1->pytest-cov==5.0.0->-r requirements.txt (line 16)) (7.6.12)
# Requirement already satisfied: tomli>=2.0.1 in /venv/main/lib/python3.10/site-packages (from pytest-env==1.1.3->-r requirements.txt (line 17)) (2.2.1)
# Requirement already satisfied: execnet>=1.1 in /venv/main/lib/python3.10/site-packages (from pytest-xdist==3.5.0->pytest-xdist[psutil]==3.5.0->-r requirements.txt (line 20)) (2.1.1)
# Requirement already satisfied: iniconfig in /venv/main/lib/python3.10/site-packages (from pytest==7.4.4->-r requirements.txt (line 21)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /venv/main/lib/python3.10/site-packages (from pytest==7.4.4->-r requirements.txt (line 21)) (1.5.0)
# Requirement already satisfied: tensorboardX>=2.2 in /venv/main/lib/python3.10/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 23)) (2.6.2.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /venv/main/lib/python3.10/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 23)) (4.12.2)
# Requirement already satisfied: sympy in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (1.13.1)
# Requirement already satisfied: networkx in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (3.3)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /venv/main/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (2.3.0)
# Requirement already satisfied: idna in /venv/main/lib/python3.10/site-packages (from trio==0.23.2->-r requirements.txt (line 29)) (3.10)
# Requirement already satisfied: outcome in /venv/main/lib/python3.10/site-packages (from trio==0.23.2->-r requirements.txt (line 29)) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /venv/main/lib/python3.10/site-packages (from trio==0.23.2->-r requirements.txt (line 29)) (1.3.1)
# Requirement already satisfied: alembic>=1.5.0 in /venv/main/lib/python3.10/site-packages (from optuna==3.5.0->-r requirements.txt (line 31)) (1.15.1)
# Requirement already satisfied: colorlog in /venv/main/lib/python3.10/site-packages (from optuna==3.5.0->-r requirements.txt (line 31)) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /venv/main/lib/python3.10/site-packages (from optuna==3.5.0->-r requirements.txt (line 31)) (2.0.38)
# Requirement already satisfied: tenacity>=6.2.0 in /venv/main/lib/python3.10/site-packages (from plotly==5.20.0->-r requirements.txt (line 32)) (9.0.0)
# Requirement already satisfied: psutil>=3.0 in /venv/main/lib/python3.10/site-packages (from pytest-xdist[psutil]==3.5.0->-r requirements.txt (line 20)) (6.1.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /venv/main/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: Mako in /venv/main/lib/python3.10/site-packages (from alembic>=1.5.0->optuna==3.5.0->-r requirements.txt (line 31)) (1.3.9)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /venv/main/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (1.18.3)
# Requirement already satisfied: decorator in /venv/main/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: lazy-loader>=0.3 in /venv/main/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /venv/main/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (3.10.1)
# Requirement already satisfied: pooch>=1.5 in /venv/main/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: six>=1.5 in /venv/main/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.0.3->-r requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests>=2.32.1->datasets==2.19.2->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.10/site-packages (from requests>=2.32.1->datasets==2.19.2->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.10/site-packages (from requests>=2.32.1->datasets==2.19.2->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /venv/main/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna==3.5.0->-r requirements.txt (line 31)) (3.1.1)
# Requirement already satisfied: cloudpickle>=1.2.1 in /venv/main/lib/python3.10/site-packages (from submitit>=1.3.3->hydra-submitit-launcher==1.2.0->-r requirements.txt (line 5)) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (6.30.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /venv/main/lib/python3.10/site-packages (from torchvision>=0.10.0->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (11.0.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /venv/main/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->-r requirements.txt (line 14)) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /venv/main/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->-r requirements.txt (line 14)) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /venv/main/lib/python3.10/site-packages (from jinja2->torch==2.3.0->-r requirements.txt (line 24)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.10/site-packages (from sympy->torch==2.3.0->-r requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /venv/main/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /venv/main/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /venv/main/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /venv/main/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /venv/main/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (3.2.1)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download and copy the dataset to this directory: `Your_Dir/emg2qwerty/data`.
# - You may now start your experiments with any scripts! Below are examples of single-user training and testing (greedy decoding).
# - **There are two ways to track the logs:**
#   - 1. Keep `--multirun`, and the logs will not be printed here, but they will be saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/submitit_logs/`.
#   - 2. Comment out `--multirun` and the logs will be printed in this notebook, but they will not be saved.

# %% [markdown]
# #### Training
#
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %%
# !python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1 \
  --multirun
# Out:
# [2025-03-14 21:52:13,892][HYDRA] Submitit 'local' sweep output dir : logs/2025-03-14/21-52-13
# [2025-03-14 21:52:13,894][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1

# %% [markdown]
# #### Testing:
#
# - Replace `Your_Path_to_Checkpoint` with your checkpoint path.

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="'/emg2qwerty-priv/logs/logs/2025-03-14/12-17-32/job0_trainer.devices=1,user=single_user/checkpoints/last.ckpt'" \
  train=False trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  # --multirun
# Out:
# [2025-03-14 12:31:27,116][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 50
#   n_freq_masks: 2
#   freq_mask_param: 4
# gaussian_noise:
#   _target_: emg2qwerty.transforms.AddGaussianNoise
# random_crop:
#   _target_: emg2qwerty.transforms.RandomCrop
#   crop_size: 500
# scaling:
#   _target_: emg2qwerty.transforms.Scaling
# reflection:
#   _target_: emg2qwerty.transforms.ReflectionAugmentation
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: false
# checkpoint: /emg2qwerty-priv/logs/logs/2025-03-14/12-17-32/job0_trainer.devices=1,user=single_user/checkpoints/last.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 40
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# Global seed set to 1501
# [2025-03-14 12:31:27,118][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2025-03-14 12:31:27,170][__main__][INFO] - Loading module from checkpoint /emg2qwerty-priv/logs/logs/2025-03-14/12-17-32/job0_trainer.devices=1,user=single_user/checkpoints/last.ckpt
# Error executing job with overrides: ['user=single_user', "checkpoint='/emg2qwerty-priv/logs/logs/2025-03-14/12-17-32/job0_trainer.devices=1,user=single_user/checkpoints/last.ckpt'", 'train=False', 'trainer.accelerator=gpu', 'decoder=ctc_greedy']
# Traceback (most recent call last):
#   File "/emg2qwerty-priv/emg2qwerty/train.py", line 67, in main
#     module = module.load_from_checkpoint(
#   File "/venv/main/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 137, in load_from_checkpoint
#     return _load_from_checkpoint(
#   File "/venv/main/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 158, in _load_from_checkpoint
#     checkpoint = pl_load(checkpoint_path, map_location=map_location)
#   File "/venv/main/lib/python3.10/site-packages/lightning_lite/utilities/cloud_io.py", line 47, in _load
#     with fs.open(path_or_url, "rb") as f:
#   File "/venv/main/lib/python3.10/site-packages/fsspec/spec.py", line 1293, in open
#     f = self._open(
#   File "/venv/main/lib/python3.10/site-packages/fsspec/implementations/local.py", line 197, in _open
#     return LocalFileOpener(path, mode, fs=self, **kwargs)
#   File "/venv/main/lib/python3.10/site-packages/fsspec/implementations/local.py", line 322, in __init__
#     self._open()
#   File "/venv/main/lib/python3.10/site-packages/fsspec/implementations/local.py", line 327, in _open
#     self.f = open(self.path, mode=self.mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/emg2qwerty-priv/logs/logs/2025-03-14/12-17-32/job0_trainer.devices=1,user=single_user/checkpoints/last.ckpt'
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
